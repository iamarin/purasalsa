# %% [markdown]
# # API INEGI
#
# @elcontrafactual
#
# Este notebook tiene la finalidad de mostrar la utilidad de la API de indicadores económicos que ofrece INEGI. Lo primero que tienen que hacer es dirigirse a la siguiente página : https://www.inegi.org.mx/servicios/api_indicadores.html. Ahí pueden encontrar toda la documentación necesaria para entender el proceso `GET` que vamos a realizar.
#
# Ya en la paǵina, deberán dirigirse al apartado **Generar consultas**, en esta sección podrán encontrar la información de los principales indicadores, más aún, encontrarán en la parte inferior una lista desplegable que les permitirá consultar la información del BIE ;), luego podrán elegir la serie de su interés y generar la consulta, OJO: en la parte inferior de la consulta aparecerá la opción **El token puede obtenerse al registrarse aquí**, sino lo tienen, pues es momento de conseguirse una llave a la información
#
# La salida de la información podrá ser en formato JSON o XML, trataré de abordar ambos formatos para familiarizarnos con la extracción. Comenzemos a codear 8)

# %% [markdown]
# Las librerias de utilizaremos seran json y requests, preferimos mantenernos fit

# %%
## los acentos se omiten intencionalmente

# librerias
import requests
import json
import pandas as pd

# %% [markdown]
# Lo primero es generar la consulta desde la página de INEGI. Yo seleccione el PIB a precios corriente. Copian el URL y, suponiendo que ya cuentan con su token, lo pegan en donde dice : '[Aquí va tu token]', lo reemplazamos todo el string con el token y...

# %%
url = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/493621/es/0700/false/BIE/2.0/XXXXXXXXXXXXXXXXXXXXXXXXXX?type=json'
response= requests.get(url)

# %% [markdown]
# Ahora vemos cual es el resultado de nuestro GET, si sale 200 ya la hicimos, si obtenemos un 400 o 500 o puede haber algún error con el servidor o la consulta no se realizó de manera adecuada.

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Ahora vamos a formar el diccionario de datos, utilizamos *.loads()* para almacenar el contenido del JSON

# %%
if response.status_code==200:
    content= json.loads(response.content)

# %%
type(content)
# Out:
# dict

# %% [markdown]
# Navegamos por el diccionario con el fin de encontrar la forma en que están almacenados los datos

# %%
content['Series']
# Out:
# [{'INDICADOR': '493621',
#   'FREQ': '6',
#   'TOPIC': '10000255011501100070',
#   'UNIT': '317',
#   'NOTE': '',
#   'SOURCE': '17',
#   'LASTUPDATE': '25/02/2020 03:49:12 p. m.',
#   'OBSERVATIONS': [{'TIME_PERIOD': '2019/04',
#     'OBS_VALUE': '18943796.095',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2019/03',
#     'OBS_VALUE': '18348814.792',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2019/02',
#     'OBS_VALUE': '18523716.904',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2019/01',
#     'OBS_VALUE': '18282105.852',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2018/04',
#     'OBS_VALUE': '19037446.164',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2018/03',
#     'OBS_VALUE': '18395545.058',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2018/02',
#     'OBS_VALUE': '18701099.826',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2018/01',
#     'OBS_VALUE': '18072389.055',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2017/04',
#     'OBS_VALUE': '18770646.685',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2017/03',
#     'OBS_VALUE': '17943735.584',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2017/02',
#     'OBS_VALUE': '18149132.22',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2017/01',
#     'OBS_VALUE': '17791095.458',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '1',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2016/04',
#     'OBS_VALUE': '18473731.771',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2016/03',
#     'OBS_VALUE': '17666882.886',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2016/02',
#     'OBS_VALUE': '17809346.28',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2016/01',
#     'OBS_VALUE': '17197681.41',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2015/04',
#     'OBS_VALUE': '17889191.246',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2015/03',
#     'OBS_VALUE': '17309618.497',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2015/02',
#     'OBS_VALUE': '17239433.696',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2015/01',
#     'OBS_VALUE': '16697180.281',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2014/04',
#     'OBS_VALUE': '17417017.092',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2014/03',
#     'OBS_VALUE': '16645075.761',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2014/02',
#     'OBS_VALUE': '16736970.616',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2014/01',
#     'OBS_VALUE': '16135555.599',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2013/04',
#     'OBS_VALUE': '16839712.526',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2013/03',
#     'OBS_VALUE': '16186046.28',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2013/02',
#     'OBS_VALUE': '16362711.037',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2013/01',
#     'OBS_VALUE': '15720278.469',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2012/04',
#     'OBS_VALUE': '16639144.561',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2012/03',
#     'OBS_VALUE': '15952746.024',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2012/02',
#     'OBS_VALUE': '16027316.825',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2012/01',
#     'OBS_VALUE': '15619687.194',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2011/04',
#     'OBS_VALUE': '16139460.314',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2011/03',
#     'OBS_VALUE': '15526005.353',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2011/02',
#     'OBS_VALUE': '15413082.337',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2011/01',
#     'OBS_VALUE': '14902786.4',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2010/04',
#     'OBS_VALUE': '15499623.401',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2010/03',
#     'OBS_VALUE': '14921450.003',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2010/02',
#     'OBS_VALUE': '14998393.281',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2010/01',
#     'OBS_VALUE': '14371712.1',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2009/04',
#     'OBS_VALUE': '14882949.237',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2009/03',
#     'OBS_VALUE': '14231940.399',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2009/02',
#     'OBS_VALUE': '14012946.412',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2009/01',
#     'OBS_VALUE': '13752157.468',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2008/04',
#     'OBS_VALUE': '15125056.475',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2008/03',
#     'OBS_VALUE': '14979493.16',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2008/02',
#     'OBS_VALUE': '15386331.873',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2008/01',
#     'OBS_VALUE': '14563429.216',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2007/04',
#     'OBS_VALUE': '15204933.405',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2007/03',
#     'OBS_VALUE': '14783297.427',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2007/02',
#     'OBS_VALUE': '14993341.591',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2007/01',
#     'OBS_VALUE': '14393731.478',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2006/04',
#     'OBS_VALUE': '14800896.843',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2006/03',
#     'OBS_VALUE': '14435867.217',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2006/02',
#     'OBS_VALUE': '14700503.814',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2006/01',
#     'OBS_VALUE': '14107961.114',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2005/04',
#     'OBS_VALUE': '14306520.447',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2005/03',
#     'OBS_VALUE': '13782142.603',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2005/02',
#     'OBS_VALUE': '14104834.676',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2005/01',
#     'OBS_VALUE': '13354792.354',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2004/04',
#     'OBS_VALUE': '13872028.155',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2004/03',
#     'OBS_VALUE': '13438257.152',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2004/02',
#     'OBS_VALUE': '13732337.644',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2004/01',
#     'OBS_VALUE': '13252637.277',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2003/04',
#     'OBS_VALUE': '13305703.424',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2003/03',
#     'OBS_VALUE': '12954912.312',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2003/02',
#     'OBS_VALUE': '13182931.645',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2003/01',
#     'OBS_VALUE': '12803326.703',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2002/04',
#     'OBS_VALUE': '13084104.346',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2002/03',
#     'OBS_VALUE': '12889950.082',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2002/02',
#     'OBS_VALUE': '13112362.78',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2002/01',
#     'OBS_VALUE': '12415541.463',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2001/04',
#     'OBS_VALUE': '12901429.2',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2001/03',
#     'OBS_VALUE': '12857408.641',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2001/02',
#     'OBS_VALUE': '12967530.187',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2001/01',
#     'OBS_VALUE': '12796119.512',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2000/04',
#     'OBS_VALUE': '13003302.172',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2000/03',
#     'OBS_VALUE': '13008792.255',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2000/02',
#     'OBS_VALUE': '12994568.9',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '2000/01',
#     'OBS_VALUE': '12725022.041',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1999/04',
#     'OBS_VALUE': '12554685.811',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1999/03',
#     'OBS_VALUE': '12325229.128',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1999/02',
#     'OBS_VALUE': '12315219.067',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1999/01',
#     'OBS_VALUE': '12100154.542',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1998/04',
#     'OBS_VALUE': '12139816.574',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1998/03',
#     'OBS_VALUE': '11972371.592',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1998/02',
#     'OBS_VALUE': '12034464.22',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1998/01',
#     'OBS_VALUE': '11827638.049',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1997/04',
#     'OBS_VALUE': '11887380.119',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1997/03',
#     'OBS_VALUE': '11408200.857',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1997/02',
#     'OBS_VALUE': '11460068.088',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1997/01',
#     'OBS_VALUE': '10862931.984',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1996/04',
#     'OBS_VALUE': '11116526.636',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1996/03',
#     'OBS_VALUE': '10583112.094',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1996/02',
#     'OBS_VALUE': '10569227.494',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1996/01',
#     'OBS_VALUE': '10426430.9',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1995/04',
#     'OBS_VALUE': '10198513.276',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1995/03',
#     'OBS_VALUE': '9802904.373',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1995/02',
#     'OBS_VALUE': '9795719.008',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1995/01',
#     'OBS_VALUE': '10189745.494',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1994/04',
#     'OBS_VALUE': '10952773.417',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1994/03',
#     'OBS_VALUE': '10602752.891',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1994/02',
#     'OBS_VALUE': '10772526.22',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1994/01',
#     'OBS_VALUE': '10343388.473',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1993/04',
#     'OBS_VALUE': '10416096.243',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1993/03',
#     'OBS_VALUE': '10066258.408',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1993/02',
#     'OBS_VALUE': '10171035.401',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1993/01',
#     'OBS_VALUE': '10008894.656',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1992/04',
#     'OBS_VALUE': '10155182.257',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1992/03',
#     'OBS_VALUE': '9607923.069',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1992/02',
#     'OBS_VALUE': '9986417.75',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1992/01',
#     'OBS_VALUE': '9701986.33',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1991/04',
#     'OBS_VALUE': '9894608.989',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1991/03',
#     'OBS_VALUE': '9176389.016',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1991/02',
#     'OBS_VALUE': '9775235.335',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1991/01',
#     'OBS_VALUE': '9268190.329',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1990/04',
#     'OBS_VALUE': '9522792.509',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1990/03',
#     'OBS_VALUE': '8885511.844',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1990/02',
#     'OBS_VALUE': '9262515.905',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1990/01',
#     'OBS_VALUE': '8964419.624',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1989/04',
#     'OBS_VALUE': '8881444.762',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1989/03',
#     'OBS_VALUE': '8452556.703',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1989/02',
#     'OBS_VALUE': '8912465.891',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1989/01',
#     'OBS_VALUE': '8575114.059',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1988/04',
#     'OBS_VALUE': '8636950.844',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1988/03',
#     'OBS_VALUE': '8031742.408',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1988/02',
#     'OBS_VALUE': '8546889.028',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1988/01',
#     'OBS_VALUE': '8378163.162',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1987/04',
#     'OBS_VALUE': '8568977.287',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1987/03',
#     'OBS_VALUE': '8038083.561',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1987/02',
#     'OBS_VALUE': '8443175.116',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1987/01',
#     'OBS_VALUE': '8119219.038',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1986/04',
#     'OBS_VALUE': '8109501.791',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1986/03',
#     'OBS_VALUE': '7769449.783',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1986/02',
#     'OBS_VALUE': '8409218.652',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1986/01',
#     'OBS_VALUE': '8208491.352',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1985/04',
#     'OBS_VALUE': '8528896.049',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1985/03',
#     'OBS_VALUE': '8193121.959',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1985/02',
#     'OBS_VALUE': '8487030.468',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1985/01',
#     'OBS_VALUE': '8539105.041',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1984/04',
#     'OBS_VALUE': '8389536.374',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1984/03',
#     'OBS_VALUE': '8119301.524',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1984/02',
#     'OBS_VALUE': '8232124.573',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1984/01',
#     'OBS_VALUE': '8384896.23',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1983/04',
#     'OBS_VALUE': '8127328.588',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1983/03',
#     'OBS_VALUE': '7764430.844',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1983/02',
#     'OBS_VALUE': '7997531.117',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1983/01',
#     'OBS_VALUE': '8120479.85',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1982/04',
#     'OBS_VALUE': '8277251.689',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1982/03',
#     'OBS_VALUE': '8198953.899',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1982/02',
#     'OBS_VALUE': '8481760.759',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1982/01',
#     'OBS_VALUE': '8512096.4',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1981/04',
#     'OBS_VALUE': '8614524.865',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1981/03',
#     'OBS_VALUE': '8211045.527',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1981/02',
#     'OBS_VALUE': '8417818.004',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1981/01',
#     'OBS_VALUE': '8229212.702',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1980/04',
#     'OBS_VALUE': '8008666.64',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1980/03',
#     'OBS_VALUE': '7478780.82',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1980/02',
#     'OBS_VALUE': '7536518.992',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'},
#    {'TIME_PERIOD': '1980/01',
#     'OBS_VALUE': '7547882.144',
#     'OBS_EXCEPTION': '',
#     'OBS_STATUS': '',
#     'OBS_SOURCE': '17',
#     'OBS_NOTE': None,
#     'COBER_GEO': '00'}]}]

# %%
content['Series'][0]
# Out:
# {'INDICADOR': '493621',
#  'FREQ': '6',
#  'TOPIC': '10000255011501100070',
#  'UNIT': '317',
#  'NOTE': '',
#  'SOURCE': '17',
#  'LASTUPDATE': '25/02/2020 03:49:12 p. m.',
#  'OBSERVATIONS': [{'TIME_PERIOD': '2019/04',
#    'OBS_VALUE': '18943796.095',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2019/03',
#    'OBS_VALUE': '18348814.792',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2019/02',
#    'OBS_VALUE': '18523716.904',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2019/01',
#    'OBS_VALUE': '18282105.852',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2018/04',
#    'OBS_VALUE': '19037446.164',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2018/03',
#    'OBS_VALUE': '18395545.058',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2018/02',
#    'OBS_VALUE': '18701099.826',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2018/01',
#    'OBS_VALUE': '18072389.055',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2017/04',
#    'OBS_VALUE': '18770646.685',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2017/03',
#    'OBS_VALUE': '17943735.584',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2017/02',
#    'OBS_VALUE': '18149132.22',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2017/01',
#    'OBS_VALUE': '17791095.458',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '1',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2016/04',
#    'OBS_VALUE': '18473731.771',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2016/03',
#    'OBS_VALUE': '17666882.886',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2016/02',
#    'OBS_VALUE': '17809346.28',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2016/01',
#    'OBS_VALUE': '17197681.41',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2015/04',
#    'OBS_VALUE': '17889191.246',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2015/03',
#    'OBS_VALUE': '17309618.497',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2015/02',
#    'OBS_VALUE': '17239433.696',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2015/01',
#    'OBS_VALUE': '16697180.281',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2014/04',
#    'OBS_VALUE': '17417017.092',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2014/03',
#    'OBS_VALUE': '16645075.761',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2014/02',
#    'OBS_VALUE': '16736970.616',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2014/01',
#    'OBS_VALUE': '16135555.599',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2013/04',
#    'OBS_VALUE': '16839712.526',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2013/03',
#    'OBS_VALUE': '16186046.28',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2013/02',
#    'OBS_VALUE': '16362711.037',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2013/01',
#    'OBS_VALUE': '15720278.469',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2012/04',
#    'OBS_VALUE': '16639144.561',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2012/03',
#    'OBS_VALUE': '15952746.024',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2012/02',
#    'OBS_VALUE': '16027316.825',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2012/01',
#    'OBS_VALUE': '15619687.194',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2011/04',
#    'OBS_VALUE': '16139460.314',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2011/03',
#    'OBS_VALUE': '15526005.353',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2011/02',
#    'OBS_VALUE': '15413082.337',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2011/01',
#    'OBS_VALUE': '14902786.4',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2010/04',
#    'OBS_VALUE': '15499623.401',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2010/03',
#    'OBS_VALUE': '14921450.003',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2010/02',
#    'OBS_VALUE': '14998393.281',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2010/01',
#    'OBS_VALUE': '14371712.1',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2009/04',
#    'OBS_VALUE': '14882949.237',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2009/03',
#    'OBS_VALUE': '14231940.399',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2009/02',
#    'OBS_VALUE': '14012946.412',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2009/01',
#    'OBS_VALUE': '13752157.468',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2008/04',
#    'OBS_VALUE': '15125056.475',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2008/03',
#    'OBS_VALUE': '14979493.16',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2008/02',
#    'OBS_VALUE': '15386331.873',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2008/01',
#    'OBS_VALUE': '14563429.216',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2007/04',
#    'OBS_VALUE': '15204933.405',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2007/03',
#    'OBS_VALUE': '14783297.427',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2007/02',
#    'OBS_VALUE': '14993341.591',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2007/01',
#    'OBS_VALUE': '14393731.478',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2006/04',
#    'OBS_VALUE': '14800896.843',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2006/03',
#    'OBS_VALUE': '14435867.217',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2006/02',
#    'OBS_VALUE': '14700503.814',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2006/01',
#    'OBS_VALUE': '14107961.114',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2005/04',
#    'OBS_VALUE': '14306520.447',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2005/03',
#    'OBS_VALUE': '13782142.603',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2005/02',
#    'OBS_VALUE': '14104834.676',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2005/01',
#    'OBS_VALUE': '13354792.354',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2004/04',
#    'OBS_VALUE': '13872028.155',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2004/03',
#    'OBS_VALUE': '13438257.152',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2004/02',
#    'OBS_VALUE': '13732337.644',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2004/01',
#    'OBS_VALUE': '13252637.277',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2003/04',
#    'OBS_VALUE': '13305703.424',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2003/03',
#    'OBS_VALUE': '12954912.312',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2003/02',
#    'OBS_VALUE': '13182931.645',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2003/01',
#    'OBS_VALUE': '12803326.703',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2002/04',
#    'OBS_VALUE': '13084104.346',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2002/03',
#    'OBS_VALUE': '12889950.082',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2002/02',
#    'OBS_VALUE': '13112362.78',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2002/01',
#    'OBS_VALUE': '12415541.463',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2001/04',
#    'OBS_VALUE': '12901429.2',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2001/03',
#    'OBS_VALUE': '12857408.641',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2001/02',
#    'OBS_VALUE': '12967530.187',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2001/01',
#    'OBS_VALUE': '12796119.512',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2000/04',
#    'OBS_VALUE': '13003302.172',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2000/03',
#    'OBS_VALUE': '13008792.255',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2000/02',
#    'OBS_VALUE': '12994568.9',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '2000/01',
#    'OBS_VALUE': '12725022.041',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1999/04',
#    'OBS_VALUE': '12554685.811',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1999/03',
#    'OBS_VALUE': '12325229.128',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1999/02',
#    'OBS_VALUE': '12315219.067',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1999/01',
#    'OBS_VALUE': '12100154.542',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1998/04',
#    'OBS_VALUE': '12139816.574',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1998/03',
#    'OBS_VALUE': '11972371.592',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1998/02',
#    'OBS_VALUE': '12034464.22',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1998/01',
#    'OBS_VALUE': '11827638.049',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1997/04',
#    'OBS_VALUE': '11887380.119',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1997/03',
#    'OBS_VALUE': '11408200.857',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1997/02',
#    'OBS_VALUE': '11460068.088',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1997/01',
#    'OBS_VALUE': '10862931.984',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1996/04',
#    'OBS_VALUE': '11116526.636',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1996/03',
#    'OBS_VALUE': '10583112.094',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1996/02',
#    'OBS_VALUE': '10569227.494',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1996/01',
#    'OBS_VALUE': '10426430.9',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1995/04',
#    'OBS_VALUE': '10198513.276',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1995/03',
#    'OBS_VALUE': '9802904.373',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1995/02',
#    'OBS_VALUE': '9795719.008',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1995/01',
#    'OBS_VALUE': '10189745.494',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1994/04',
#    'OBS_VALUE': '10952773.417',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1994/03',
#    'OBS_VALUE': '10602752.891',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1994/02',
#    'OBS_VALUE': '10772526.22',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1994/01',
#    'OBS_VALUE': '10343388.473',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1993/04',
#    'OBS_VALUE': '10416096.243',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1993/03',
#    'OBS_VALUE': '10066258.408',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1993/02',
#    'OBS_VALUE': '10171035.401',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1993/01',
#    'OBS_VALUE': '10008894.656',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1992/04',
#    'OBS_VALUE': '10155182.257',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1992/03',
#    'OBS_VALUE': '9607923.069',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1992/02',
#    'OBS_VALUE': '9986417.75',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1992/01',
#    'OBS_VALUE': '9701986.33',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1991/04',
#    'OBS_VALUE': '9894608.989',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1991/03',
#    'OBS_VALUE': '9176389.016',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1991/02',
#    'OBS_VALUE': '9775235.335',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1991/01',
#    'OBS_VALUE': '9268190.329',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1990/04',
#    'OBS_VALUE': '9522792.509',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1990/03',
#    'OBS_VALUE': '8885511.844',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1990/02',
#    'OBS_VALUE': '9262515.905',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1990/01',
#    'OBS_VALUE': '8964419.624',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1989/04',
#    'OBS_VALUE': '8881444.762',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1989/03',
#    'OBS_VALUE': '8452556.703',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1989/02',
#    'OBS_VALUE': '8912465.891',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1989/01',
#    'OBS_VALUE': '8575114.059',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1988/04',
#    'OBS_VALUE': '8636950.844',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1988/03',
#    'OBS_VALUE': '8031742.408',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1988/02',
#    'OBS_VALUE': '8546889.028',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1988/01',
#    'OBS_VALUE': '8378163.162',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1987/04',
#    'OBS_VALUE': '8568977.287',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1987/03',
#    'OBS_VALUE': '8038083.561',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1987/02',
#    'OBS_VALUE': '8443175.116',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1987/01',
#    'OBS_VALUE': '8119219.038',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1986/04',
#    'OBS_VALUE': '8109501.791',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1986/03',
#    'OBS_VALUE': '7769449.783',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1986/02',
#    'OBS_VALUE': '8409218.652',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1986/01',
#    'OBS_VALUE': '8208491.352',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1985/04',
#    'OBS_VALUE': '8528896.049',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1985/03',
#    'OBS_VALUE': '8193121.959',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1985/02',
#    'OBS_VALUE': '8487030.468',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1985/01',
#    'OBS_VALUE': '8539105.041',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1984/04',
#    'OBS_VALUE': '8389536.374',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1984/03',
#    'OBS_VALUE': '8119301.524',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1984/02',
#    'OBS_VALUE': '8232124.573',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1984/01',
#    'OBS_VALUE': '8384896.23',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1983/04',
#    'OBS_VALUE': '8127328.588',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1983/03',
#    'OBS_VALUE': '7764430.844',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1983/02',
#    'OBS_VALUE': '7997531.117',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1983/01',
#    'OBS_VALUE': '8120479.85',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1982/04',
#    'OBS_VALUE': '8277251.689',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1982/03',
#    'OBS_VALUE': '8198953.899',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1982/02',
#    'OBS_VALUE': '8481760.759',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1982/01',
#    'OBS_VALUE': '8512096.4',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1981/04',
#    'OBS_VALUE': '8614524.865',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1981/03',
#    'OBS_VALUE': '8211045.527',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1981/02',
#    'OBS_VALUE': '8417818.004',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1981/01',
#    'OBS_VALUE': '8229212.702',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1980/04',
#    'OBS_VALUE': '8008666.64',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1980/03',
#    'OBS_VALUE': '7478780.82',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1980/02',
#    'OBS_VALUE': '7536518.992',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'},
#   {'TIME_PERIOD': '1980/01',
#    'OBS_VALUE': '7547882.144',
#    'OBS_EXCEPTION': '',
#    'OBS_STATUS': '',
#    'OBS_SOURCE': '17',
#    'OBS_NOTE': None,
#    'COBER_GEO': '00'}]}

# %%
content['Series'][0]['OBSERVATIONS']
# Out:
# [{'TIME_PERIOD': '2019/04',
#   'OBS_VALUE': '18943796.095',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2019/03',
#   'OBS_VALUE': '18348814.792',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2019/02',
#   'OBS_VALUE': '18523716.904',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2019/01',
#   'OBS_VALUE': '18282105.852',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2018/04',
#   'OBS_VALUE': '19037446.164',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2018/03',
#   'OBS_VALUE': '18395545.058',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2018/02',
#   'OBS_VALUE': '18701099.826',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2018/01',
#   'OBS_VALUE': '18072389.055',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2017/04',
#   'OBS_VALUE': '18770646.685',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2017/03',
#   'OBS_VALUE': '17943735.584',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2017/02',
#   'OBS_VALUE': '18149132.22',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2017/01',
#   'OBS_VALUE': '17791095.458',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '1',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2016/04',
#   'OBS_VALUE': '18473731.771',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2016/03',
#   'OBS_VALUE': '17666882.886',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2016/02',
#   'OBS_VALUE': '17809346.28',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2016/01',
#   'OBS_VALUE': '17197681.41',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2015/04',
#   'OBS_VALUE': '17889191.246',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2015/03',
#   'OBS_VALUE': '17309618.497',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2015/02',
#   'OBS_VALUE': '17239433.696',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2015/01',
#   'OBS_VALUE': '16697180.281',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2014/04',
#   'OBS_VALUE': '17417017.092',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2014/03',
#   'OBS_VALUE': '16645075.761',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2014/02',
#   'OBS_VALUE': '16736970.616',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2014/01',
#   'OBS_VALUE': '16135555.599',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2013/04',
#   'OBS_VALUE': '16839712.526',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2013/03',
#   'OBS_VALUE': '16186046.28',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2013/02',
#   'OBS_VALUE': '16362711.037',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2013/01',
#   'OBS_VALUE': '15720278.469',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2012/04',
#   'OBS_VALUE': '16639144.561',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2012/03',
#   'OBS_VALUE': '15952746.024',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2012/02',
#   'OBS_VALUE': '16027316.825',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2012/01',
#   'OBS_VALUE': '15619687.194',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2011/04',
#   'OBS_VALUE': '16139460.314',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2011/03',
#   'OBS_VALUE': '15526005.353',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2011/02',
#   'OBS_VALUE': '15413082.337',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2011/01',
#   'OBS_VALUE': '14902786.4',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2010/04',
#   'OBS_VALUE': '15499623.401',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2010/03',
#   'OBS_VALUE': '14921450.003',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2010/02',
#   'OBS_VALUE': '14998393.281',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2010/01',
#   'OBS_VALUE': '14371712.1',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2009/04',
#   'OBS_VALUE': '14882949.237',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2009/03',
#   'OBS_VALUE': '14231940.399',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2009/02',
#   'OBS_VALUE': '14012946.412',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2009/01',
#   'OBS_VALUE': '13752157.468',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2008/04',
#   'OBS_VALUE': '15125056.475',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2008/03',
#   'OBS_VALUE': '14979493.16',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2008/02',
#   'OBS_VALUE': '15386331.873',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2008/01',
#   'OBS_VALUE': '14563429.216',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2007/04',
#   'OBS_VALUE': '15204933.405',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2007/03',
#   'OBS_VALUE': '14783297.427',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2007/02',
#   'OBS_VALUE': '14993341.591',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2007/01',
#   'OBS_VALUE': '14393731.478',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2006/04',
#   'OBS_VALUE': '14800896.843',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2006/03',
#   'OBS_VALUE': '14435867.217',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2006/02',
#   'OBS_VALUE': '14700503.814',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2006/01',
#   'OBS_VALUE': '14107961.114',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2005/04',
#   'OBS_VALUE': '14306520.447',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2005/03',
#   'OBS_VALUE': '13782142.603',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2005/02',
#   'OBS_VALUE': '14104834.676',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2005/01',
#   'OBS_VALUE': '13354792.354',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2004/04',
#   'OBS_VALUE': '13872028.155',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2004/03',
#   'OBS_VALUE': '13438257.152',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2004/02',
#   'OBS_VALUE': '13732337.644',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2004/01',
#   'OBS_VALUE': '13252637.277',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2003/04',
#   'OBS_VALUE': '13305703.424',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2003/03',
#   'OBS_VALUE': '12954912.312',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2003/02',
#   'OBS_VALUE': '13182931.645',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2003/01',
#   'OBS_VALUE': '12803326.703',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2002/04',
#   'OBS_VALUE': '13084104.346',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2002/03',
#   'OBS_VALUE': '12889950.082',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2002/02',
#   'OBS_VALUE': '13112362.78',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2002/01',
#   'OBS_VALUE': '12415541.463',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2001/04',
#   'OBS_VALUE': '12901429.2',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2001/03',
#   'OBS_VALUE': '12857408.641',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2001/02',
#   'OBS_VALUE': '12967530.187',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2001/01',
#   'OBS_VALUE': '12796119.512',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2000/04',
#   'OBS_VALUE': '13003302.172',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2000/03',
#   'OBS_VALUE': '13008792.255',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2000/02',
#   'OBS_VALUE': '12994568.9',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2000/01',
#   'OBS_VALUE': '12725022.041',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1999/04',
#   'OBS_VALUE': '12554685.811',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1999/03',
#   'OBS_VALUE': '12325229.128',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1999/02',
#   'OBS_VALUE': '12315219.067',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1999/01',
#   'OBS_VALUE': '12100154.542',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1998/04',
#   'OBS_VALUE': '12139816.574',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1998/03',
#   'OBS_VALUE': '11972371.592',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1998/02',
#   'OBS_VALUE': '12034464.22',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1998/01',
#   'OBS_VALUE': '11827638.049',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1997/04',
#   'OBS_VALUE': '11887380.119',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1997/03',
#   'OBS_VALUE': '11408200.857',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1997/02',
#   'OBS_VALUE': '11460068.088',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1997/01',
#   'OBS_VALUE': '10862931.984',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1996/04',
#   'OBS_VALUE': '11116526.636',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1996/03',
#   'OBS_VALUE': '10583112.094',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1996/02',
#   'OBS_VALUE': '10569227.494',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1996/01',
#   'OBS_VALUE': '10426430.9',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1995/04',
#   'OBS_VALUE': '10198513.276',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1995/03',
#   'OBS_VALUE': '9802904.373',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1995/02',
#   'OBS_VALUE': '9795719.008',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1995/01',
#   'OBS_VALUE': '10189745.494',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1994/04',
#   'OBS_VALUE': '10952773.417',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1994/03',
#   'OBS_VALUE': '10602752.891',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1994/02',
#   'OBS_VALUE': '10772526.22',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1994/01',
#   'OBS_VALUE': '10343388.473',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1993/04',
#   'OBS_VALUE': '10416096.243',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1993/03',
#   'OBS_VALUE': '10066258.408',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1993/02',
#   'OBS_VALUE': '10171035.401',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1993/01',
#   'OBS_VALUE': '10008894.656',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1992/04',
#   'OBS_VALUE': '10155182.257',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1992/03',
#   'OBS_VALUE': '9607923.069',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1992/02',
#   'OBS_VALUE': '9986417.75',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1992/01',
#   'OBS_VALUE': '9701986.33',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1991/04',
#   'OBS_VALUE': '9894608.989',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1991/03',
#   'OBS_VALUE': '9176389.016',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1991/02',
#   'OBS_VALUE': '9775235.335',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1991/01',
#   'OBS_VALUE': '9268190.329',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1990/04',
#   'OBS_VALUE': '9522792.509',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1990/03',
#   'OBS_VALUE': '8885511.844',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1990/02',
#   'OBS_VALUE': '9262515.905',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1990/01',
#   'OBS_VALUE': '8964419.624',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1989/04',
#   'OBS_VALUE': '8881444.762',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1989/03',
#   'OBS_VALUE': '8452556.703',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1989/02',
#   'OBS_VALUE': '8912465.891',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1989/01',
#   'OBS_VALUE': '8575114.059',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1988/04',
#   'OBS_VALUE': '8636950.844',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1988/03',
#   'OBS_VALUE': '8031742.408',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1988/02',
#   'OBS_VALUE': '8546889.028',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1988/01',
#   'OBS_VALUE': '8378163.162',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1987/04',
#   'OBS_VALUE': '8568977.287',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1987/03',
#   'OBS_VALUE': '8038083.561',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1987/02',
#   'OBS_VALUE': '8443175.116',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1987/01',
#   'OBS_VALUE': '8119219.038',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1986/04',
#   'OBS_VALUE': '8109501.791',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1986/03',
#   'OBS_VALUE': '7769449.783',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1986/02',
#   'OBS_VALUE': '8409218.652',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1986/01',
#   'OBS_VALUE': '8208491.352',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1985/04',
#   'OBS_VALUE': '8528896.049',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1985/03',
#   'OBS_VALUE': '8193121.959',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1985/02',
#   'OBS_VALUE': '8487030.468',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1985/01',
#   'OBS_VALUE': '8539105.041',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1984/04',
#   'OBS_VALUE': '8389536.374',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1984/03',
#   'OBS_VALUE': '8119301.524',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1984/02',
#   'OBS_VALUE': '8232124.573',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1984/01',
#   'OBS_VALUE': '8384896.23',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1983/04',
#   'OBS_VALUE': '8127328.588',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1983/03',
#   'OBS_VALUE': '7764430.844',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1983/02',
#   'OBS_VALUE': '7997531.117',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1983/01',
#   'OBS_VALUE': '8120479.85',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1982/04',
#   'OBS_VALUE': '8277251.689',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1982/03',
#   'OBS_VALUE': '8198953.899',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1982/02',
#   'OBS_VALUE': '8481760.759',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1982/01',
#   'OBS_VALUE': '8512096.4',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1981/04',
#   'OBS_VALUE': '8614524.865',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1981/03',
#   'OBS_VALUE': '8211045.527',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1981/02',
#   'OBS_VALUE': '8417818.004',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1981/01',
#   'OBS_VALUE': '8229212.702',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1980/04',
#   'OBS_VALUE': '8008666.64',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1980/03',
#   'OBS_VALUE': '7478780.82',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1980/02',
#   'OBS_VALUE': '7536518.992',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '1980/01',
#   'OBS_VALUE': '7547882.144',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'}]

# %% [markdown]
# La llave 'Series' nos da acceso a los datos de interés, so vamos a extraer la info, la ponemos en una lista y luego pegamos como marco de datos

# %%
series=content['Series'][0]['OBSERVATIONS']   
    
#Obtención de la lista de observaciones 
valor = []
periodo = []
for obs in series:  
    valor.append(float(obs['OBS_VALUE']))
    periodo.append(str(obs['TIME_PERIOD']))
    
data = list(zip(periodo[:],valor[:]))
data = pd.DataFrame(data)

# %% [markdown]
# Voilá!, ahora ya podemos utilizar nuestra API de consulta para cualquier serie

# %%
data
# Out:
#            0             1
# 0    2019/04  1.894380e+07
# 1    2019/03  1.834881e+07
# 2    2019/02  1.852372e+07
# 3    2019/01  1.828211e+07
# 4    2018/04  1.903745e+07
# 5    2018/03  1.839555e+07
# 6    2018/02  1.870110e+07
# 7    2018/01  1.807239e+07
# 8    2017/04  1.877065e+07
# 9    2017/03  1.794374e+07
# 10   2017/02  1.814913e+07
# 11   2017/01  1.779110e+07
# 12   2016/04  1.847373e+07
# 13   2016/03  1.766688e+07
# 14   2016/02  1.780935e+07
# 15   2016/01  1.719768e+07
# 16   2015/04  1.788919e+07
# 17   2015/03  1.730962e+07
# 18   2015/02  1.723943e+07
# 19   2015/01  1.669718e+07
# 20   2014/04  1.741702e+07
# 21   2014/03  1.664508e+07
# 22   2014/02  1.673697e+07
# 23   2014/01  1.613556e+07
# 24   2013/04  1.683971e+07
# 25   2013/03  1.618605e+07
# 26   2013/02  1.636271e+07
# 27   2013/01  1.572028e+07
# 28   2012/04  1.663914e+07
# 29   2012/03  1.595275e+07
# ..       ...           ...
# 130  1987/02  8.443175e+06
# 131  1987/01  8.119219e+06
# 132  1986/04  8.109502e+06
# 133  1986/03  7.769450e+06
# 134  1986/02  8.409219e+06
# 135  1986/01  8.208491e+06
# 136  1985/04  8.528896e+06
# 137  1985/03  8.193122e+06
# 138  1985/02  8.487030e+06
# 139  1985/01  8.539105e+06
# 140  1984/04  8.389536e+06
# 141  1984/03  8.119302e+06
# 142  1984/02  8.232125e+06
# 143  1984/01  8.384896e+06
# 144  1983/04  8.127329e+06
# 145  1983/03  7.764431e+06
# 146  1983/02  7.997531e+06
# 147  1983/01  8.120480e+06
# 148  1982/04  8.277252e+06
# 149  1982/03  8.198954e+06
# 150  1982/02  8.481761e+06
# 151  1982/01  8.512096e+06
# 152  1981/04  8.614525e+06
# 153  1981/03  8.211046e+06
# 154  1981/02  8.417818e+06
# 155  1981/01  8.229213e+06
# 156  1980/04  8.008667e+06
# 157  1980/03  7.478781e+06
# 158  1980/02  7.536519e+06
# 159  1980/01  7.547882e+06
#
# [160 rows x 2 columns]
